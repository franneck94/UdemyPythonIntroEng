# %%
import os

# %%
PROJECT_DIR = (
    r"C:\Users\Jan\OneDrive\_Coding\UdemyPythonIntroEng\Chapter5_Intermediate"
)

# %%
PROJECT_DIR = (
    "C:/Users/Jan/OneDrive/_Coding/UdemyPythonIntroEng/Chapter5_Intermediate"
)

# %%
input_filepath = os.path.join(PROJECT_DIR, "test.txt")
output_filepath = os.path.join(PROJECT_DIR, "test_out.txt")

# %%
with open(input_filepath) as file:
    content = file.readlines()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with open(input_filepath) as file:
#       2     content = file.readlines()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Jan/OneDrive/_Coding/UdemyPythonIntroEng/Chapter5_Intermediate\\test.txt'

# %%
print(content)
content.append("Tom Tomerson\n")
# Out:
# ['Jan Schaffranek\n', 'Peter Peterson\n']

# %%
with open(output_filepath, "w") as file:
    file.writelines(content)
