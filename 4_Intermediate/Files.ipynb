# %%
import os

# %%
PROJECT_DIR = (
    r"C:\Users\Jan\OneDrive\_Coding\UdemyPythonIntroEng\Chapter4_Intermediate"
)

input_filepath = os.path.join(PROJECT_DIR, "test.txt")
output_filepath = os.path.join(PROJECT_DIR, "test_out.txt")

# %%
with open(input_filepath) as file:
    content = file.readlines()

# %%
print(content)
content.append("Tom Tomerson\n")
# Out:
# ['Jan Schaffranek\n', 'Peter Peterson\n']

# %%
with open(output_filepath, "w") as file:
    file.writelines(content)
