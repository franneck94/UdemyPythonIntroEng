# %%
name = "Jan Schaffranek"

# %%
result = name.find("an")

if result == -1:
    print("Not found")
else:
    print("Found at index: ", result)
# Out:
# Found at index:  1

# %%
name2 = name.replace("Jan", "Yann")
print(name)
print(name2)
# Out:
# Jan Schaffranek
# Yann Schaffranek

# %%
name3 = name.upper()
print(name3)
# Out:
# JAN SCHAFFRANEK

# %%
name4 = name.lower()
print(name4)
# Out:
# jan schaffranek

# %%
name5 = name.split(" ")
print(name5)
# Out:
# ['Jan', 'Schaffranek']

# %%
count = name.count("an")
print(count)
# Out:
# 2

# %%
my_value1 = 27
my_value2 = "Jan"

# %%
stupid_str = "Age: " + str(my_value1) + "Name: " + str(my_value2)
print(stupid_str)
# Out:
# Age: 27Name: Jan

# %%
smart_str = f"Age: {my_value1} Name: {my_value2}"
print(smart_str)
# Out:
# Age: 27 Name: Jan
